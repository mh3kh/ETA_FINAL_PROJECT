# %% [markdown]
# Juliet Holmes mh3kh@virginia.edu
#
# DS 5001
#
# August 2022
#
# # 1b_Get data to STADM (F0 to F2)- part 2
#
# The purpose of this notebook is to do some additional data cleaning on widpedia-DOC_v2.csv.
#
# ---
#
# dependencies: wikipedia-DOC_v2.csv
#
# output: wikipedia-DOC_v3.csv

# %% [markdown]
# ---
# ---

# %%
import pandas as pd

# %%
LIB = pd.read_csv("wikipedia-DOC_v2.csv").set_index('doc_id')

# %%
LIB
# Out:
#                               doc_title  \
# doc_id
# 0                    Abstract data type
# 1                     Associative array
# 2                         Augmented map
# 3                         Cardinal tree
# 4       Collection (abstract data type)
# ...                                 ...
# 4585                 Variable shadowing
# 4586    Volatile (computer programming)
# 4587                   Google Chart API
# 4588                      Google Charts
# 4589         JavaScript InfoVis Toolkit
#
#                                                   doc_url  \
# doc_id
# 0        https://en.wikipedia.org/wiki/Abstract_data_type
# 1         https://en.wikipedia.org/wiki/Associative_array
# 2             https://en.wikipedia.org/wiki/Augmented_map
# 3             https://en.wikipedia.org/wiki/Cardinal_tree
# 4       https://en.wikipedia.org/wiki/Collection_(abst...
# ...                                                   ...
# ...

# %%
#check for any null values in doc_summary
LIB[LIB['doc_summary'].isnull()]
# Out:
#                                         doc_title  \
# doc_id
# 1310    Comparison of CDMI server implementations
#
#                                                   doc_url doc_summary  \
# doc_id
# 1310    https://en.wikipedia.org/wiki/Comparison_of_CD...         NaN
#
#        doc_content       categories
# doc_id
# 1310           NaN  Data management

# %%
#remove "Comparison of CDMI server implementations". The doc_summary is null because it is just a table on the wiki page. 

LIB = LIB.dropna()

# %%
# Removes HTML tags and entities, then remaining LaTeX stuff,
# then removes newlines and collapses remaining spaces.

LIB['doc_summary_clean'] = LIB.doc_summary.str.replace(r"<[^>]+>", "", regex=True)\
    .str.replace(r"\sNaN\s", " ", regex = True)\
    .str.replace(r"\snan\s", " ", regex = True)\
    .str.replace(r"&\w+;", " ", regex=True)\
    .str.replace(r"\{\\\w+.+\}", " ", regex=True)\
    .str.replace(r"\n+", " ", regex=True)\
    .str.replace(r"\s+", " ", regex=True)\
# Out:
# <ipython-input-6-beddfa002482>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LIB['doc_summary_clean'] = LIB.doc_summary.str.replace(r"<[^>]+>", "", regex=True)\

# %%
LIB['doc_content_clean'] = LIB.doc_content.str.replace(r"<[^>]+>", "", regex=True)\
    .str.replace(r"\sNaN\s", " ", regex = True)\
    .str.replace(r"\snan\s", " ", regex = True)\
    .str.replace(r"&\w+;", " ", regex=True)\
    .str.replace(r"\{\\\w+.+\}", " ", regex=True)\
    .str.replace(r"\n+", " ", regex=True)\
    .str.replace(r"\s+", " ", regex=True)
# Out:
# <ipython-input-7-178246744a21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LIB['doc_content_clean'] = LIB.doc_content.str.replace(r"<[^>]+>", "", regex=True)\

# %%
LIB.head()
# Out:
#                               doc_title  \
# doc_id
# 0                    Abstract data type
# 1                     Associative array
# 2                         Augmented map
# 3                         Cardinal tree
# 4       Collection (abstract data type)
#
#                                                   doc_url  \
# doc_id
# 0        https://en.wikipedia.org/wiki/Abstract_data_type
# 1         https://en.wikipedia.org/wiki/Associative_array
# 2             https://en.wikipedia.org/wiki/Augmented_map
# 3             https://en.wikipedia.org/wiki/Cardinal_tree
# 4       https://en.wikipedia.org/wiki/Collection_(abst...
#
#                                               doc_summary  \
# doc_id
# 0       <p>In computer science, an <b>abstract data ty...
# 1       <link rel="mw-deduplicated-inline-style" href=...
# 2       <p>In computer science, the <b>augmented map</...
# 3       <p>A <b>cardinal tree</b> (or trie) of degree ...
# ...

# %%
#remove duplicate "abstract data types"
LIB["categories"] = LIB["categories"].replace('Abstract data types|Abstract data types', 'Abstract data types')
# Out:
# <ipython-input-9-8c15ca64310b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LIB["categories"] = LIB["categories"].replace('Abstract data types|Abstract data types', 'Abstract data types')

# %%
LIB
# Out:
#                               doc_title  \
# doc_id
# 0                    Abstract data type
# 1                     Associative array
# 2                         Augmented map
# 3                         Cardinal tree
# 4       Collection (abstract data type)
# ...                                 ...
# 4585                 Variable shadowing
# 4586    Volatile (computer programming)
# 4587                   Google Chart API
# 4588                      Google Charts
# 4589         JavaScript InfoVis Toolkit
#
#                                                   doc_url  \
# doc_id
# 0        https://en.wikipedia.org/wiki/Abstract_data_type
# 1         https://en.wikipedia.org/wiki/Associative_array
# 2             https://en.wikipedia.org/wiki/Augmented_map
# 3             https://en.wikipedia.org/wiki/Cardinal_tree
# 4       https://en.wikipedia.org/wiki/Collection_(abst...
# ...                                                   ...
# ...

# %% [markdown]
# # Save

# %%
LIB.to_csv("wikipedia-DOC_v3.csv")
